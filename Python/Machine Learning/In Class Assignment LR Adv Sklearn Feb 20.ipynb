# %%
import pandas as pd

# %%
df = pd.read_csv("Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  Total spent  sales
# 0  230.1   37.8       69.2        337.1   22.1
# 1   44.5   39.3       45.1        128.9   10.4
# 2   17.2   45.9       69.3        132.4    9.3
# 3  151.5   41.3       58.5        251.3   18.5
# 4  180.8   10.8       58.4        250.0   12.9

# %%
import matplotlib.pyplot as plt
plt.scatter(df['TV'], df['sales'])

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Total spent'], df['sales'])

# %%
X = df[['TV', 'radio', 'newspaper']]   # Without .values()
#X
#X.values
X.shape
y = df['sales']

# %%
# https://scikit-learn.org/stable/
from sklearn.model_selection import train_test_split

# %%
#help(train_test_split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (134, 3)

# %%
X_test.shape
# Out:
# (66, 3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
df.head()
# Out:
#       TV  radio  newspaper  Total spent  sales
# 0  230.1   37.8       69.2        337.1   22.1
# 1   44.5   39.3       45.1        128.9   10.4
# 2   17.2   45.9       69.3        132.4    9.3
# 3  151.5   41.3       58.5        251.3   18.5
# 4  180.8   10.8       58.4        250.0   12.9

# %%
# Review MAE, MSE, RMSE for the exam 
from sklearn import metrics
print(f'Coefficient: {model.coef_}')
print(f'Intercept: {model.intercept_}')
print(f'Mean Absolute Error (MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Mean Squared Error (MSE): {metrics.mean_squared_error(y_test, y_pred)}')
print(f'Root Mean Squared Error (RMSE): {metrics.mean_squared_error(y_test, y_pred, squared=False)}')
# Out:
# Coefficient: [0.04466512 0.19663006 0.00607439]
# Intercept: 2.7580716192171018
# Mean Absolute Error (MAE): 1.493775002472897
# Mean Squared Error (MSE): 3.7279283306815096
# Root Mean Squared Error (RMSE): 1.9307843822347202

# %%
df.head()
# Out:
#       TV  radio  newspaper  Total spent  sales
# 0  230.1   37.8       69.2        337.1   22.1
# 1   44.5   39.3       45.1        128.9   10.4
# 2   17.2   45.9       69.3        132.4    9.3
# 3  151.5   41.3       58.5        251.3   18.5
# 4  180.8   10.8       58.4        250.0   12.9

# %%
new_data = pd.DataFrame({'TV': [180.8], 'radio': [10.8], 'newspaper': [58.4]})
new_data
# Out:
#       TV  radio  newspaper
# 0  180.8   10.8       58.4

# %%
new_prediction = model.predict(new_data)
print(f'Predicted Sales: {new_prediction}')
# Out:
# Predicted Sales: [13.31187428]
